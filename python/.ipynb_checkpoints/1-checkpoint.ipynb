# %%
import json
# Python 模块化
from openai import OpenAI
# python 实例化不需要new
client=OpenAI(
    api_key='sk-e1068fd3f1e34115bdb046f14be13baa',
    base_url='https://api.deepseek.com/v1'
)
def send_messages(messages):
    response=client.chat.completions.create(
        model='deepseek-reasoner',
        messages=messages,
#         告诉大模型可以调用tools
        tools=tools,
#         让大模型自由选择
        tool_choice='auto'
    )
    return response
# openai 定义的tool 接口标准
tools = [
    # 创建tool  JSON申明
    {
        # tool 就是一个函数
        "type": "function",
        "function": {
            "name": "get_closing_price",
            # 自然语言处理
            "description": "获取指定股票的收盘价",
            "parameters": {
                "type": "object",
                "properties": {
                    "name": {
                        "type": "string",
                        "description": "股票名称"
                    }
                },
                "required": ["name"]
            }
        }
    }
]
def  get_closing_price(name):
        if name =='青岛啤酒':
            return '5555'
        else:
            return '未找到该股票'
messages=[{'role':'user','content':'青岛啤酒的收盘价是多少？'}]
response= send_messages(messages)
message=response.choices[0].message
print(message)
ChatCompletionMessage(content='我来帮您查询青岛啤酒的收盘价。', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_00_1yN8O6igyHYL6L69lB0C3tjd', function=Function(arguments='{"name": "青岛啤酒"}', name='get_closing_price'), type='function', index=0)])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import json
#       2 # Python 模块化
# ----> 3 from openai import OpenAI
#       4 # python 实例化不需要new
#       5 client=OpenAI(
#       6     api_key='sk-e1068fd3f1e34115bdb046f14be13baa',
#       7     base_url='https://api.deepseek.com/v1'
#       8 )
#
# ModuleNotFoundError: No module named 'openai'
